# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import klib

# %%
d = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding='latin-1')
d
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
d.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
d.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
d.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
# for typing columns names without difficulty

d.columns = d.columns.str.lower()
d.columns
# Out:
# Index(['area code', 'area', 'item code', 'item', 'element code', 'element',
#        'unit', 'y2014', 'y2015', 'y2016', 'y2017', 'y2018'],
#       dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area code     60943 non-null  int64
#  1   area          60943 non-null  object
#  2   item code     60943 non-null  int64
#  3   item          60943 non-null  object
#  4   element code  60943 non-null  int64
#  5   element       60943 non-null  object
#  6   unit          60943 non-null  object
#  7   y2014         59354 non-null  float64
#  8   y2015         59395 non-null  float64
#  9   y2016         59408 non-null  float64
#  10  y2017         59437 non-null  float64
#  11  y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
d.nunique()
# Out:
# area code         49
# area              49
# item code        122
# item             119
# element code      18
# element           18
# unit               5
# y2014           4493
# y2015           4520
# y2016           4520
# y2017           4537
# y2018           4591
# dtype: int64

# %%
for i in d.columns[4:7]:
    print(f'{i} - {d[i].unique()}')
# Out:
# element code - [ 511 5301  664  674  684 5511 5611 5072 5911 5521 5527 5123 5131 5154
#  5170 5142  645 5171]
# element - ['Total Population - Both sexes' 'Domestic supply quantity'
#  'Food supply (kcal/capita/day)' 'Protein supply quantity (g/capita/day)'
#  'Fat supply quantity (g/capita/day)' 'Production' 'Import Quantity'
#  'Stock Variation' 'Export Quantity' 'Feed' 'Seed' 'Losses' 'Processing'
#  'Other uses (non-food)' 'Residuals' 'Food'
#  'Food supply quantity (kg/capita/yr)' 'Tourist consumption']
# unit - ['1000 persons' '1000 tonnes' 'kcal/capita/day' 'g/capita/day' 'kg']

# %%
d.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# **CODE FOR THE QUIZ**

# %%
d.head()
# Out:
#    area code     area  item code         item  element code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   element             unit     y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       y2015     y2016     y2017     y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
d.isnull().sum()
# Out:
# area code          0
# area               0
# item code          0
# item               0
# element code       0
# element            0
# unit               0
# y2014           1589
# y2015           1548
# y2016           1535
# y2017           1506
# y2018           1436
# dtype: int64

# %%
d.groupby(['element'])['y2017'].sum()
# Out:
# element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
d.groupby(['element'])['y2014'].sum()
# Out:
# element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
d.groupby(['element'])['y2015'].sum()
# Out:
# element
# Domestic supply quantity                  2021493.55
# Export Quantity                            157614.47
# Fat supply quantity (g/capita/day)          10235.74
# Feed                                       225050.22
# Food                                      1232361.10
# Food supply (kcal/capita/day)              453383.00
# Food supply quantity (kg/capita/yr)         49345.13
# Import Quantity                            267018.46
# Losses                                     155439.00
# Other uses (non-food)                       66254.41
# Processing                                 287929.00
# Production                                1947019.39
# Protein supply quantity (g/capita/day)      11833.95
# Residuals                                   30045.00
# Seed                                        23976.82
# Stock Variation                             34910.99
# Total Population - Both sexes             1058081.00
# Tourist consumption                           349.00
# ...

# %%
d.groupby(['element'])['y2016'].sum()
# Out:
# element
# Domestic supply quantity                  2044842.70
# Export Quantity                            151920.46
# Fat supply quantity (g/capita/day)          10102.77
# Feed                                       228958.65
# Food                                      1247022.17
# Food supply (kcal/capita/day)              451810.00
# Food supply quantity (kg/capita/yr)         48985.28
# Import Quantity                            286582.78
# Losses                                     157787.00
# Other uses (non-food)                       69563.68
# Processing                                 280631.00
# Production                                1943537.15
# Protein supply quantity (g/capita/day)      11779.69
# Residuals                                   37224.00
# Seed                                        23389.20
# Stock Variation                             33140.12
# Total Population - Both sexes             1085107.00
# Tourist consumption                            89.00
# ...

# %%
d.groupby(['element'])['y2018'].sum()
# Out:
# element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
d.nunique()
# Out:
# area code         49
# area              49
# item code        122
# item             119
# element code      18
# element           18
# unit               5
# y2014           4493
# y2015           4520
# y2016           4520
# y2017           4537
# y2018           4591
# dtype: int64

# %%
d.groupby(['area'])['y2017'].sum().sort_values()
# Out:
# area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
d.groupby(['item'])['y2015'].sum()
# Out:
# item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: y2015, Length: 119, dtype: float64

# %%
d.groupby(['item'])['y2018'].sum()
# Out:
# item
# Alcohol, Non-Food        2293.00
# Alcoholic Beverages     97847.27
# Animal Products         11578.61
# Animal fats            269648.27
# Apples and products      9640.51
#                          ...
# Vegetables, Other      163987.21
# Vegetal Products       107775.39
# Wheat and products     242645.19
# Wine                     4039.32
# Yams                   221272.09
# Name: y2018, Length: 119, dtype: float64

# %%
klib.corr_mat(d)
# Out:
# <style type="text/css">
# ...

# %%
d.describe(include='all')
# Out:
#            area code   area     item code                     item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         element code                   element         unit          y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
d[['element code','y2014','y2015','y2016','y2017','y2018']].corr()
# Out:
#               element code     y2014     y2015     y2016     y2017     y2018
# element code      1.000000  0.024457  0.023889  0.023444  0.024254  0.024279
# y2014             0.024457  1.000000  0.994647  0.996081  0.995230  0.994872
# y2015             0.023889  0.994647  1.000000  0.995739  0.988048  0.988208
# y2016             0.023444  0.996081  0.995739  1.000000  0.992785  0.992757
# y2017             0.024254  0.995230  0.988048  0.992785  1.000000  0.998103
# y2018             0.024279  0.994872  0.988208  0.992757  0.998103  1.000000

# %%
p = pd.DataFrame(d.groupby(['area','element'])['y2015'].sum().sort_values()).reset_index()
p
# Out:
#              area                   element      y2015
# 0    South Africa           Stock Variation   -7238.00
# 1           Sudan           Stock Variation   -2748.00
# 2          Rwanda           Stock Variation   -1429.00
# 3          Zambia           Stock Variation   -1037.00
# 4    South Africa                 Residuals    -893.00
# ..            ...                       ...        ...
# 798         Egypt                Production  205548.03
# 799       Nigeria                      Food  231454.02
# 800         Egypt  Domestic supply quantity  245789.22
# 801       Nigeria                Production  385670.13
# 802       Nigeria  Domestic supply quantity  406045.65
#
# [803 rows x 3 columns]

# %%
p[p['area'] == 'Madagascar']
# Out:
#            area                                 element     y2015
# 10   Madagascar                               Residuals   -616.00
# 13   Madagascar                         Stock Variation   -505.00
# 147  Madagascar      Fat supply quantity (g/capita/day)     91.85
# 185  Madagascar  Protein supply quantity (g/capita/day)    173.05
# 325  Madagascar                         Export Quantity    494.75
# 347  Madagascar                                    Seed    699.00
# 371  Madagascar     Food supply quantity (kg/capita/yr)    871.59
# 457  Madagascar                         Import Quantity   1721.80
# 462  Madagascar                              Processing   1803.00
# 482  Madagascar                                    Feed   2070.22
# 490  Madagascar                                  Losses   2176.00
# 541  Madagascar                   Other uses (non-food)   3957.12
# 596  Madagascar           Food supply (kcal/capita/day)   7685.00
# ...
